# %% [markdown]
# # Ex 1. Generate 1000 random points (x,y)

# %%
import numpy as np

# %%
x=np.random.randn(1000)
y=x+0.4*np.random.randn(1000)

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel("x coordinate")
plt.ylabel("y coordinate")
plt.show()

# %% [markdown]
# # Build a simple linear regression from scratch

# %%
X=x

# %%
Y=y

# %%
mean_x=X.mean()
mean_y=Y.mean()
shape=(len(X),1)
y_pred1=np.empty(shape)

# %%
l=len(X)
a=0
b=0
for i in range(l):
    a+=(X[i]*Y[i])-(mean_y)*X[i]
    b+=((X[i])*(X[i]))-(mean_x)*X[i]
    #print("y_predicted=",y_pred)
m1 =a/b
c1=mean_y-(m1*mean_x)
y_pred1[i]=m1*X[i]+c
print('c =',c1)
print('m =',m1)
slope, intercept = np.polyfit(x, y, 1)
y_pred1
# Out:
# c = -0.007635637515644139
# m = 0.9745113827104978
# array([[ 4.31924236e-01],
#        [ 8.88013267e-01],
#        [ 4.82123672e-01],
#        [ 3.38322869e-01],
#        [-3.34032092e-02],
#        [-1.60594712e+00],
#        [ 2.70541582e-01],
#        [ 1.69056685e+00],
#        [ 5.37918821e-01],
#        [ 1.33582609e+00],
#        [-8.70928883e-01],
#        [ 1.44385866e+00],
#        [-1.86967753e-01],
#        [ 7.70717017e-01],
#        [-8.07834076e-01],
#        [-4.82009183e-01],
#        [ 1.40786708e+00],
#        [-2.45909366e-01],
#        [-8.89402688e-01],
#        [ 5.58279385e-02],
#        [-1.08676611e+00],
#        [ 3.48870519e-02],
#        [-4.60758963e-01],
#        [ 3.20245301e-01],
#        [-2.20574971e-01],
#        [ 9.24323659e-02],
#        [-2.80035681e-02],
#        [ 9.92179076e-01],
#        [ 1.18284630e-01],
#        [ 6.16695118e-01],
#        [ 1.03103222e+00],
#        [ 1.94387749e+00],
#        [-5.13670586e-01],
# ...

# %%
intercept
# Out:
# -0.007635637515644252

# %%
slope
# Out:
# 0.9745113827104982

# %%
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)), color = 'k')
plt.scatter(x, y) 
plt.show()

# %%
mse=0
for i in range(l):
    mse+=(y_pred[i]-Y[i])*(y_pred[i]-Y[i])
print('c =',c)
print('m =',m)
mse=mse/l
print("Error = ",e)
from math import sqrt
rmse=sqrt(mse)
print("RMSE",rmse)
# Out:
# c = -0.007635637515644139
# m = 1.0038564599685025
# Error =  [1.10295213]
# RMSE 1.1213641081428227

# %% [markdown]
# # Use gradient descent to find the optimal slope and intercept value

# %%
m=0
y_new=np.empty(shape)
c=0
n=len(X)
current_w=0.1
learning_rate = 0.01
iteration=1000

for i in range(iteration):
    mse=sum((y - m*x+c)**2)/1000
    Dm = -2/n * (sum(X * (y - m*x+c)))
    Dc = -2/n * (sum(y - (m*x+c)))
    m = m - (learning_rate * Dm)
    c = c - (learning_rate * Dc)
    print(f"Iteration {i+1}: Cost {mse}, Weight \
        #{m}, Bias {c}")
bfl=m*X+c
plt.scatter(x,y)
plt.plot(x,bfl,c='b')
print(m,c)
# Out:
# Iteration 1: Cost 1.1519467496801548, Weight         #0.020176143459859602, Bias 0.000579816402612169
# Iteration 2: Cost 1.1116936715396366, Weight         #0.03993487995747075, Bias 0.0011328702989825308
# Iteration 3: Cost 1.0730885209108394, Weight         #0.059284833767872996, Bias 0.001660010699314979
# Iteration 4: Cost 1.036063845125367, Weight         #0.07823445119775285, Bias 0.0021620631508396018
# Iteration 5: Cost 1.0005549523521318, Weight         #0.09679200425348639, Bias 0.0026398303408489542
# Iteration 6: Cost 0.9664997985986883, Weight         #0.11496559423367059, Bias 0.0030940926849163716
# Iteration 7: Cost 0.9338388793373581, Weight         #0.13276315524769694, Bias 0.0035256089006494556
# Iteration 8: Cost 0.9025151255668441, Weight         #0.15019245766188716, Bias 0.003935116567323623
# Iteration 9: Cost 0.8724738041278266, Weight         #0.16726111147468106, Bias 0.00432333267173255
# ...

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.25,
                                                random_state=666)
x_train=pd.DataFrame(x_train)
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
x_train.values.reshape(-1,1)

reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(reg.intercept_)
print(reg.coef_)
# Out:
# -0.005580084523956624
# [0.97222786]

# %%
x_test=pd.DataFrame(x_test)
y_pred = reg.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math

print('mae:', mean_absolute_error(y_test,y_pred))
print('mse:', math.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# mae: 0.3353749058853159
# mse: 0.4126504824022377

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test,y_test, c='r')
plt.plot(x_test,y_pred, c='b')

# %% [markdown]
# # Inference

# %% [markdown]
# Normal linear regression takes less time to compute the parameters and the results are almost similar in terms of accuracy.
# Normal Linear regression seems to be better than Gradient descent

# %% [markdown]
# # Linear regression

# %%
print('intercept_1 =',c1)
print('slope_1 =',m1)
slope, intercept = np.polyfit(x, y, 1)
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)), color = 'k')
plt.scatter(x, y) 
plt.show()
# Out:
# intercept_1 = -0.007635637515644139
# slope_1 = 0.9745113827104978

# %% [markdown]
# # Using gradient descent

# %%
bfl=m*X+c
plt.scatter(x,y)
plt.plot(x,bfl,c='b')
print("slope_2=",m)
print("intercept_2=",c)
# Out:
# slope_2= 0.9739578454401718
# intercept_2= -0.007614832329647461

# %% [markdown]
# # Using sklearn

# %%
print("intercept_3=",reg.intercept_)
print("slope_3=",reg.coef_)
import matplotlib.pyplot as plt
plt.scatter(x_test,y_test, c='b')
plt.plot(x_test,y_pred, c='r')
# Out:
# intercept_3= -0.005580084523956624
# slope_3= [0.97222786]
